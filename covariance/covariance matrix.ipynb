# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats 
import seaborn as sn


# df = pd.DataFrame({"A":[7, 9, 1, 5],  
#                    "B":[13, 6, 8, 1], 
#                    "C":[1, 3, 8, 12], 
#                    "D":[4, 12, 8, 10]})

df = pd.read_csv('daily_update.csv').fillna(0)

df.head()
df.shape
# Out:
# (59, 18)

# %%
def covariance(a,b):
    if len(a) != len(b):
        return

    a_mean = np.mean(a)
    b_mean = np.mean(b)

    sum = 0

    for i in range(0, len(a)):
        sum += ((a[i] - a_mean) * (b[i] - b_mean))

    return sum/(len(a)-1)

# print(covariance(df['A'], df['B']))
# dataset = np.array([[7,9,1,5], [13, 6, 8,1]])
# print(np.cov(dataset))

# %%
# alabama_subset = df[df['Province_State'] == 'Alabama']
# deaths = [alabama_subset["Deaths"]]
# confirmed = [alabama_subset["Confirmed"]]

# # alabama_subset.corr(['Deaths']["Confirmed"])
# # answer = deaths.corr(conf

total_deaths = df['Deaths'].sum()
print(total_deaths)
total_confirmed = df["Confirmed"].sum()
print(total_confirmed)
total_recovered = df["Recovered"].sum()
total_hospital = df["Hospitalization_Rate"].sum()
# Out:
# 22019
# 555313
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-e85b30045990> in <module>
#      13 total_hospital = df["Hospitalization_Rate"].sum()
#      14
# ---> 15 total_deaths.corr(total_confirmed)
#      16
#      17
#
# AttributeError: 'numpy.int64' object has no attribute 'corr'

# %%
alabama_confirmed = (alabama_subset["Confirmed"])
print(alabama_confirmed)
# alabama_deaths = (alabama_subset["Deaths"])
# whatever = (alabama_subset["Lat"])
# # print(covariance(alabama_confirmed, alabama_deaths))

# print(covariance(df['A'], df['B']))
# dataset = np.array([[7,9,1,5], [13, 6, 8,1]])
# print(np.cov(dataset))
# Out:
# 0    3563
# Name: Confirmed, dtype: int64

# %%
alabama_subset.corr()
# Out:
#                       Confirmed  Deaths  Recovered  Active  Incident_Rate  \
# Confirmed                   NaN     NaN        NaN     NaN            NaN
# Deaths                      NaN     NaN        NaN     NaN            NaN
# Recovered                   NaN     NaN        NaN     NaN            NaN
# Active                      NaN     NaN        NaN     NaN            NaN
# Incident_Rate               NaN     NaN        NaN     NaN            NaN
# People_Tested               NaN     NaN        NaN     NaN            NaN
# People_Hospitalized         NaN     NaN        NaN     NaN            NaN
# Mortality_Rate              NaN     NaN        NaN     NaN            NaN
# Testing_Rate                NaN     NaN        NaN     NaN            NaN
# Hospitalization_Rate        NaN     NaN        NaN     NaN            NaN
#
#                       People_Tested  People_Hospitalized  Mortality_Rate  \
# Confirmed                       NaN                  NaN             NaN
# ...

# %%
df = df.drop(["Lat", "Long_", "UID", "FIPS"], axis=1)

# %%
plt.show()
sn.heatmap(df.corr(), annot=True)

# %%
confirmed = df["Confirmed"]
deaths = df["Deaths"]
tested = df["People_Tested"]
hospitalized = df["People_Hospitalized"]
recovered = df["Recovered"]
state = df["Province_State"]


# print(confirmed)

print("covariance between confirmed cases and deaths =", covariance(confirmed, deaths))
print("numpy cov =", np.cov(confirmed, deaths)[0][1])
print('\n')
print("covariance between deaths and deaths =", covariance(deaths, deaths))
print("numpy cov =", np.cov(deaths, deaths)[0][1])
print("\n")
print("covarinace between confirmed cases and recovered cases =", covariance(confirmed, recovered))
print("numpy cov =", np.cov(confirmed, recovered)[0][1])
print("\n")
print("covariance between hospitalized and recovered =", covariance(hospitalized, recovered))
print('numpy cov =', np.cov(hospitalized, recovered)[0][1])
print("\n")
print("covariance between tested and hospitalized patients =", covariance(tested, hospitalized))
print("numpy cov =", np.cov(tested, hospitalized)[0][1])
print("\n")
print("covariance between hospitalized and deaths =", covariance(hospitalized, deaths))
print("numpy cov =", np.cov(hospitalized, deaths)[0][1])


# print(covariance(alabama_confirmed, alabama_deaths))

whatever = covariance(confirmed, deaths)

print(whatever)

# sns.distplot(df['Confirmed'].dropna(), hist=True, kde=True, bins=16)
# Out:
# covariance between confirmed cases and deaths = 32267282.085914668
# numpy cov = 32267282.085914668
#
#
# covariance between deaths and deaths = 1579643.8199883108
# numpy cov = 1579643.8199883108
#
#
# covarinace between confirmed cases and recovered cases = 67959303.67679718
# numpy cov = 67959303.67679718
#
#
# covariance between hospitalized and recovered = 15856058.081531271
# numpy cov = 15856058.08153127
#
#
# covariance between tested and hospitalized patients = 347103177.4704851
# numpy cov = 347103177.4704851
#
#
# covariance between hospitalized and deaths = 6987833.104909412
# numpy cov = 6987833.104909411
# 32267282.085914668

# %%
df.head()
# Out:
#   Province_State Country_Region          Last_Update  Confirmed  Deaths  \
# 0        Alabama             US  2020-04-12 23:18:15       3563      93
# 1         Alaska             US  2020-04-12 23:18:15        272       8
# 2        Arizona             US  2020-04-12 23:18:15       3542     115
# 3       Arkansas             US  2020-04-12 23:18:15       1280      27
# 4     California             US  2020-04-12 23:18:15      22795     640
#
#    Recovered  Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 0        0.0    3470      75.988020        21583.0                437.0
# 1       66.0     264      45.504049         8038.0                 31.0
# 2        0.0    3427      48.662422        42109.0                  0.0
# 3      367.0    1253      49.439423        19722.0                130.0
# 4        0.0   22155      58.137726       190328.0               5234.0
#
#    Mortality_Rate ISO3  Testing_Rate  Hospitalization_Rate
# ...

# %%
df[df["Deaths"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bcaba194f757> in <module>
# ----> 1 df[df["Deaths"]]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ...
